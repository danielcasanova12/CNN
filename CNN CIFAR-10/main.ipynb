# %%
# %pip install keras
# %pip install tensorflow
# %pip install numpy
# %pip install matplotlib
# %pip install pandas
# %pip install seaborn

import tensorflow as tf
from keras.datasets import cifar10

print("TensorFlow version:", tf.__version__)
print("Keras version:", tf.keras.__version__)
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Requirement already satisfied: keras in f:\git\cnn\myenv\lib\site-packages (3.4.1)
# Requirement already satisfied: absl-py in f:\git\cnn\myenv\lib\site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in f:\git\cnn\myenv\lib\site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in f:\git\cnn\myenv\lib\site-packages (from keras) (13.7.1)
# Requirement already satisfied: namex in f:\git\cnn\myenv\lib\site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in f:\git\cnn\myenv\lib\site-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in f:\git\cnn\myenv\lib\site-packages (from keras) (0.12.1)
# Requirement already satisfied: ml-dtypes in f:\git\cnn\myenv\lib\site-packages (from keras) (0.3.2)
# Requirement already satisfied: packaging in f:\git\cnn\myenv\lib\site-packages (from keras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in f:\git\cnn\myenv\lib\site-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in f:\git\cnn\myenv\lib\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in f:\git\cnn\myenv\lib\site-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in f:\git\cnn\myenv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tensorflow in f:\git\cnn\myenv\lib\site-packages (2.16.2)
# Requirement already satisfied: tensorflow-intel==2.16.2 in f:\git\cnn\myenv\lib\site-packages (from tensorflow) (2.16.2)
# Requirement already satisfied: absl-py>=1.0.0 in f:\git\cnn\myenv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in f:\git\cnn\myenv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in f:\git\cnn\myenv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in f:\git\cnn\myenv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in f:\git\cnn\myenv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in f:\git\cnn\myenv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in f:\git\cnn\myenv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in f:\git\cnn\myenv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in f:\git\cnn\myenv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in f:\git\cnn\myenv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in f:\git\cnn\myenv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in f:\git\cnn\myenv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in f:\git\cnn\myenv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in f:\git\cnn\myenv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in f:\git\cnn\myenv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in f:\git\cnn\myenv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in f:\git\cnn\myenv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in f:\git\cnn\myenv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in f:\git\cnn\myenv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in f:\git\cnn\myenv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in f:\git\cnn\myenv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (0.31.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in f:\git\cnn\myenv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in f:\git\cnn\myenv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.2->tensorflow) (0.43.0)
# Requirement already satisfied: rich in f:\git\cnn\myenv\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (13.7.1)
# Requirement already satisfied: namex in f:\git\cnn\myenv\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (0.0.8)
# Requirement already satisfied: optree in f:\git\cnn\myenv\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in f:\git\cnn\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in f:\git\cnn\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in f:\git\cnn\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in f:\git\cnn\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in f:\git\cnn\myenv\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in f:\git\cnn\myenv\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in f:\git\cnn\myenv\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in f:\git\cnn\myenv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in f:\git\cnn\myenv\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in f:\git\cnn\myenv\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in f:\git\cnn\myenv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in f:\git\cnn\myenv\lib\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in f:\git\cnn\myenv\lib\site-packages (3.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in f:\git\cnn\myenv\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in f:\git\cnn\myenv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in f:\git\cnn\myenv\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in f:\git\cnn\myenv\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in f:\git\cnn\myenv\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in f:\git\cnn\myenv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in f:\git\cnn\myenv\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in f:\git\cnn\myenv\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in f:\git\cnn\myenv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in f:\git\cnn\myenv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in f:\git\cnn\myenv\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in f:\git\cnn\myenv\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in f:\git\cnn\myenv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in f:\git\cnn\myenv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in f:\git\cnn\myenv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in f:\git\cnn\myenv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in f:\git\cnn\myenv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in f:\git\cnn\myenv\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in f:\git\cnn\myenv\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in f:\git\cnn\myenv\lib\site-packages (from seaborn) (3.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in f:\git\cnn\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in f:\git\cnn\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in f:\git\cnn\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in f:\git\cnn\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in f:\git\cnn\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in f:\git\cnn\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in f:\git\cnn\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in f:\git\cnn\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in f:\git\cnn\myenv\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in f:\git\cnn\myenv\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in f:\git\cnn\myenv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# TensorFlow version: 2.16.2
# Keras version: 3.4.1

# %%
from keras.datasets import cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

x_train /= 255
x_test /= 255

y_train = y_train.flatten()
y_test = y_test.flatten()

# %%
from keras.layers import Input, Conv2D, Dense, Flatten, Dropout, MaxPooling2D, BatchNormalization
from keras.models import Model
from keras.optimizers import Adam
i = Input(shape=x_train[0].shape)

layer = Conv2D(32, (3, 3), activation='relu', padding='same')(i)
layer = BatchNormalization()(layer)
layer = MaxPooling2D((2, 2))(layer)

layer = Conv2D(64, (3, 3), activation='relu', padding='same')(layer)
layer = BatchNormalization()(layer)
layer = MaxPooling2D((2, 2))(layer)

layer = Conv2D(128, (3, 3), activation='relu', padding='same')(layer)
layer = BatchNormalization()(layer)
layer = MaxPooling2D((2, 2))(layer)

layer = Flatten()(layer)
layer = Dropout(0.5)(layer)
layer = Dense(512, activation='relu')(layer)
layer = Dropout(0.5)(layer)
layer = Dense(10, activation='softmax')(layer)

model = Model(i, layer)

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train, epochs=15, validation_data=(x_test, y_test))
# Out:
# Epoch 1/15
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 68s 42ms/step - accuracy: 0.3558 - loss: 2.0567 - val_accuracy: 0.4993 - val_loss: 1.5171
# Epoch 2/15
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 51s 33ms/step - accuracy: 0.5367 - loss: 1.2965 - val_accuracy: 0.6275 - val_loss: 1.0871
# Epoch 3/15
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 46s 30ms/step - accuracy: 0.6089 - loss: 1.1142 - val_accuracy: 0.6594 - val_loss: 0.9729
# Epoch 4/15
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 43s 28ms/step - accuracy: 0.6454 - loss: 1.0200 - val_accuracy: 0.6855 - val_loss: 0.9056
# Epoch 5/15
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 39s 25ms/step - accuracy: 0.6778 - loss: 0.9299 - val_accuracy: 0.7155 - val_loss: 0.8248
# Epoch 6/15
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 50s 32ms/step - accuracy: 0.6961 - loss: 0.8804 - val_accuracy: 0.7170 - val_loss: 0.8033
# Epoch 7/15
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 76s 28ms/step - accuracy: 0.7189 - loss: 0.8157 - val_accuracy: 0.7086 - val_loss: 0.8357
# Epoch 8/15
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 44s 28ms/step - accuracy: 0.7332 - loss: 0.7661 - val_accuracy: 0.7265 - val_loss: 0.7985
# Epoch 9/15
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 44s 28ms/step - accuracy: 0.7468 - loss: 0.7312 - val_accuracy: 0.7218 - val_loss: 0.8233
# Epoch 10/15
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 45s 29ms/step - accuracy: 0.7621 - loss: 0.6887 - val_accuracy: 0.7562 - val_loss: 0.7414
# Epoch 11/15
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 45s 28ms/step - accuracy: 0.7745 - loss: 0.6506 - val_accuracy: 0.7741 - val_loss: 0.6561
# Epoch 12/15
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 45s 29ms/step - accuracy: 0.7851 - loss: 0.6193 - val_accuracy: 0.7596 - val_loss: 0.7131
# Epoch 13/15
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 45s 28ms/step - accuracy: 0.7967 - loss: 0.5878 - val_accuracy: 0.7906 - val_loss: 0.6210
# Epoch 14/15
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 45s 29ms/step - accuracy: 0.7981 - loss: 0.5748 - val_accuracy: 0.7701 - val_loss: 0.6805
# Epoch 15/15
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 45s 29ms/step - accuracy: 0.8076 - loss: 0.5472 - val_accuracy: 0.7881 - val_loss: 0.6168

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Configurar o estilo dos gráficos
sns.set(style='dark', palette='Set2', font_scale=1.2, rc={'figure.figsize': [14, 6]})

# Criar a figura com subplots
plt.figure(figsize=(16, 6))

# Subplot para acurácia
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', linewidth=2)
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
plt.title('Training and Validation Accuracy', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)

# Subplot para perda
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
plt.title('Training and Validation Loss', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)

# Ajustar o layout
plt.tight_layout(pad=3.0)
plt.subplots_adjust(top=0.9)
plt.show()
